# %% [markdown]
# <a href="https://colab.research.google.com/github/amarsinhrampatil/bostonhousepricing/blob/main/task_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perform EDA on below insurance dataset
#
# Link: https://www.kaggle.com/datasets/thedevastator/insurance-claim-analysis-demographic-and-health
#
# Perform All steps of EDA and document conclusions and then perform feature engineering.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1= pd.read_csv('insurance_data.csv')

# %%
df= df1.copy()

# %%
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %% [markdown]
# ## COLUMN TYPES
# 1.NUMERICAL COLUMNS- index,PatientID,bmi, bloodpressure, claim
# 2. categorical- gender, diabetic,smoker,childeren,region
# 3. mixed- no mixed columns

# %%
df['age'].describe()
# Out:
# count    1335.000000
# mean       38.078652
# std        11.102924
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
df['age'].plot(kind= 'hist',bins= 10)

# %%
df['age'].plot(kind= 'kde')

# %%
df['age'].skew()
# Out:
# 0.11361133741072633

# %%
df['age'].plot(kind='box')

# %%
df['age'].isnull().sum()
# Out:
# 5

# %% [markdown]
# CONCLUSIONS
#
#
# 1.   age is normally distributed
# 2.   5 values are missing
# 3.   no outliers are present

# %% [markdown]
# ### **bmi**

# %% [markdown]
# CONCLUSIONS
#
# 1.   bmi is normally distributed
# 2.   NO MISSING VALUES
# 3. some outliers are present
#
#
# *   List item

# %%
df['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %%
df['bmi'].isnull().sum()
# Out:
# 0

# %%
df['bmi'].plot(kind= 'hist')

# %%
df['bmi'].skew()
# Out:
# 0.28597245020808587

# %%
df['bmi'].plot(kind= 'kde')

# %%
df['bmi'].plot(kind= 'box')

# %%
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 9         9         10  30.0    male  53.1             97       No         0
# 141     141        142  46.0    male  50.4             89      Yes         1
# 675     675        676  49.0  female  48.1             81      Yes         2
# 802     802        803  42.0    male  49.1            109      Yes         0
# 1299   1299       1300  50.0    male  52.6            110       No         1
#
#      smoker     region     claim
# 9        No  northwest   1163.46
# 141      No  southeast   2438.06
# 675      No  northeast   9432.93
# 802      No  southeast  11381.33
# 1299    Yes  southeast  44501.40

# %% [markdown]
# **BLOODPRESSURE**

# %%
df['bloodpressure'].describe()
# Out:
# count    1340.000000
# mean       94.157463
# std        11.434712
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
df['bloodpressure'].isnull().sum()
# Out:
# 0

# %%
df['bloodpressure'].skew()
# Out:
# 1.4835342102293079

# %%
df['bloodpressure'].plot(kind= 'hist')

# %%
df['bloodpressure'].plot(kind= 'kde')

# %%
df['bloodpressure'].plot(kind= 'box')

# %%
df[df['bloodpressure'] > 120]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1147   1147       1148  29.0  female  32.7            128      Yes         2
# 1150   1150       1151  55.0  female  27.1            135       No         1
# 1152   1152       1153  38.0  female  35.9            128       No         1
# 1153   1153       1154  43.0    male  36.8            126       No         2
# 1154   1154       1155  31.0    male  23.8            126      Yes         0
# 1156   1156       1157  46.0  female  23.0            137      Yes         0
# 1161   1161       1162  22.0    male  22.4            137      Yes         2
# 1166   1166       1167  23.0    male  26.7            123      Yes         0
# 1169   1169       1170  27.0    male  36.7            130       No         1
# 1174   1174       1175  44.0  female  29.1            139       No         0
# 1181   1181       1182  32.0    male  28.6            132       No         0
# ...

# %% [markdown]
# CONCLUSIONS
#
#
# 1.   data is left skewed distributed
# 2.   no missing values
# 3. outliers present

# %% [markdown]
# ### **CLAIM**

# %%
df['claim'].describe()
# Out:
# count     1340.000000
# mean     13252.745642
# std      12109.609288
# min       1121.870000
# 25%       4719.685000
# 50%       9369.615000
# 75%      16604.305000
# max      63770.430000
# Name: claim, dtype: float64

# %%
df['claim'].isnull().sum()
# Out:
# 0

# %%
df['claim'].skew()
# Out:
# 1.5167468509489237

# %%
df['claim'].plot(kind= 'hist')

# %%
df['claim'].plot(kind= 'kde')

# %%
df['claim'].plot(kind= 'box')

# %% [markdown]
# **CONCLUSIONS**
#
#
# 1.   NOT NORMALLY DISTRIBUTED
# 2.   OUTLIERS ARE PRESENT
# 3. NO MISSING VALUES

# %% [markdown]
# CATEGORIAL COLUMNS- gender, diabetic,smoker,childeren,region

# %%
df['gender'].value_counts()
# Out:
# male      678
# female    662
# Name: gender, dtype: int64

# %%
df['gender'].value_counts().plot(kind= 'bar')

# %%
df['gender'].value_counts().plot(kind= 'pie', autopct='%0.01f%%')

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %% [markdown]
# DIEBETIC

# %%
df['diabetic'].value_counts()
# Out:
# No     698
# Yes    642
# Name: diabetic, dtype: int64

# %%
df['diabetic'].value_counts().plot(kind='bar')

# %%
df['diabetic'].value_counts().plot(kind= 'pie', autopct='%0.01f%%')

# %%
df['diabetic'].isnull().sum()
# Out:
# 0

# %% [markdown]
# SMOKER

# %%
df['smoker'].value_counts()
# Out:
# No     1066
# Yes     274
# Name: smoker, dtype: int64

# %%
df['smoker'].value_counts().plot(kind= "bar")

# %%
df['smoker'].value_counts().plot(kind= "pie", autopct= '%0.01f%%')

# %%
df['smoker'].isnull().sum()
# Out:
# 0

# %% [markdown]
# CHILDREN

# %%
df['children'].value_counts()
# Out:
# 0    576
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df['children'].value_counts().plot(kind= 'bar')

# %%
df['children'].value_counts().plot(kind= 'pie',autopct= '%0.01f%%')

# %%
df['children'].isnull().sum()
# Out:
# 0

# %% [markdown]
# REGION

# %%
df['region'].value_counts()
# Out:
# southeast    443
# northwest    349
# southwest    314
# northeast    231
# Name: region, dtype: int64

# %%
df['region'].value_counts().plot(kind= 'bar')

# %%
df['region'].value_counts().plot(kind= 'pie',autopct= '%0.01f%%')

# %%
df['region'].isnull().sum()
# Out:
# 3

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
df.corr()
# Out:
#                   index  PatientID       age       bmi  bloodpressure  \
# index          1.000000   1.000000 -0.007492  0.115129       0.450602
# PatientID      1.000000   1.000000 -0.007492  0.115129       0.450602
# age           -0.007492  -0.007492  1.000000 -0.041955      -0.060325
# bmi            0.115129   0.115129 -0.041955  1.000000       0.143544
# bloodpressure  0.450602   0.450602 -0.060325  0.143544       1.000000
# children       0.128104   0.128104 -0.025547  0.012092      -0.031682
# claim          0.879268   0.879268 -0.027909  0.197401       0.531341
#
#                children     claim
# index          0.128104  0.879268
# PatientID      0.128104  0.879268
# age           -0.025547 -0.027909
# bmi            0.012092  0.197401
# bloodpressure -0.031682  0.531341
# children       1.000000  0.069233
# claim          0.069233  1.000000

# %%
sns.heatmap(df[df.corr()])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.8/dist-packages/seaborn/matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-793233543f91> in <module>
# ----> 1 sns.heatmap(df[df.corr()])
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.pairplot(df)
